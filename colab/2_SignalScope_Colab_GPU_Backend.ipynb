# %% [markdown]
# # SignalScope — Google Colab GPU Backend Server
# ### Host the FastAPI Backend on Free Colab GPU with Public HTTPS Tunnel
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vishvjani/sih-project/blob/master/notebooks/2_SignalScope_Colab_GPU_Backend.ipynb)
#
# This notebook runs the complete SignalScope FastAPI backend directly inside Google Colab using GPU acceleration, and exposes a public HTTPS endpoint via **localtunnel** or **pyngrok**.
# You can then paste this URL into your React Frontend (`VITE_API_URL`) to run live inferences powered by Colab GPU!

# %% [markdown]
# ## Step 1: Check GPU & Clone Repository

# %%
# !nvidia-smi
# !git clone https://github.com/vishvjani/sih-project.git /content/sih-project || (cd /content/sih-project && git pull)
# %cd /content/sih-project/repo

# %% [markdown]
# ## Step 2: Install Backend & Tunnel Requirements

# %%
# !pip install -q fastapi uvicorn pydantic python-multipart pillow numpy timm torchvision pyngrok
# !npm install -g localtunnel

# %% [markdown]
# ## Step 3: Launch FastAPI Server & Expose Public URL
# Run the backend in the background and expose port 8000 via localtunnel.

# %%
import subprocess
import time
import urllib.request

# Start FastAPI server on port 8000
print('Starting FastAPI server...')
server_process = subprocess.Popen(['uvicorn', 'src.app.main:app', '--host', '0.0.0.0', '--port', '8000'])
time.sleep(3)

# Print public IP (localtunnel password)
try:
    public_ip = urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip()
    print(f'\n👉 Your Tunnel Password / IP is: {public_ip}')
except Exception:
    pass
print('Starting localtunnel on port 8000...')
# !npx localtunnel --port 8000
